# %% [markdown]
# Este cuaderno es el segundo de dos cuadernos introductorios al lenguaje de programación Python.
#
# En el tutorial anterior vimos algunos aspectos básicos de la programación en Python, como los diferentes tipos de datos que se puede manejar, en qué tipo de contenedores podemos almacenarlos y operaciones básicas sobre los mismos.
# En este cuaderno veremos algunas bibliotecas base de Python, como lo son Pandas, Numpy y Matplotlib. Estas bibliotecas permiten manipular otros tipos de datos más complejos como los arrays de Numpy, los DataFrames y series de Pandas. Luego, Matplotlib es una librería que cuenta con funciones para graficar nuestras secuencias de datos.
#
# Este cuaderno fue generado por Valentina Gascue para el Curso "Redes Neuronales como modelos de Cognición", tomando como referencia los cuadernos generados previamente en el curso Neurociencia Cognitivo Computacional.

# %% [markdown]
# ## Sobre los paquetes en Python
#
# En el cuaderno anterior aún no utilizamos ninguna librería de Python. Estas son conjuntos de código generado por la comunidad que resuelven problemas comúnes que uno puede tener al programar en python, a la vez que expanden las funcionalidades del mismo.
#
# Las librerías que presentaremos aquí son bloques esenciales en cualquier trabajo de redes neuronales (y de programacion en general) en Python.
#
# Al ser agregados a la base del lenguaje de programación debemos primero instalarlas y posteriormente cargarlas cuando las queramos usar. Al estar usando google collab, las librerias base de python ya están instaladas pero por una guia sobre como instalar paquetes puede consultar esta [fuente](https://packaging.python.org/en/latest/tutorials/installing-packages/#).
#
# En la siguiente celda importaremos las librerias a utilizar en este cuaderno, no olvide correr la celda para que queden cargadas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# La sintaxis allí utilizada se aplica para cualquier paquete.
# Notará que en los tres casos utilizamos 'as' seguido de una abreviatura. Esto se conoce como 'alias' y se usan ciertos alias convencionales para paquetes grandes como estos.
#
# Lo que permiten los alias es que cuando haya que hacer referencia en el código a ese paquete solo baste con usar el alias y no el nombre completo.

# %% [markdown]
# # **Numpy**
#
# Numpy es un paquete central en el desarrollo de funcionalidades en ciencia de datos y aplicaciones de redes neuronales. Su nombre surge como abreviatura de 'numerical python' y es, de hecho, lo que brinda: funcionalidad para trabajar con datos numéricos de manera rápida y eficiente.
#
# El tipo de datos que brinda Numpy son las numpy arrays (matriz en español), que se pueden manipular matematicamente de la misma manera que las matrices.

# %% [markdown]
# ### Generación de numpy arrays

# %% [markdown]
# Hay muchas formas de generar numpy arrays, aquí discutiremos algunas básicas.

# %% [markdown]
# Se puede iniciar una numpy array vacia o llena de ceros o unos con las siguientes funciones:

# %% [markdown]
# *Numpy array vacía*:
#
# ```
# np.empty(dimensión)
# ```
#
# A la función "empty", perteneciente al paquete numpy (np) se le debe dar como argumento las dimensiones de la matriz que queremos que genere, por ejemplo: (2,1) generara una matriz vacia de dos filas y 1 columna.

# %%
#Genere una numpy array vacia y corrobore el tipo de dato que genera

# %% [markdown]
# De forma análoga a la np array vacia se pueden generar np arrays rellenas con ceros o unos
# *Numpy array de ceros*:
# ```
# np.zeros(dimension)
# ```
# *Numpy array de unos*:
# ```
# np.ones(dimension)
# ```

# %% [markdown]
# También se pueden generar numpy arrays con rangos, similar a lo visto anteriormente con las listas generadas a partir de la función 'range()'.
#
# Numpy tiene una función integrada '**np.linspace(i,j,k)**' que genera arrays numericas con un rango entre i y j con k elementos. Si bien es similar a la función 'range()' notar que en aquella se le definia el salto entre datos consecutivos mientras que a np.linspace() se le indica el numero de datos totales que quiero que contenga mi matriz.

# %% [markdown]
# *Ejercicio*
#
# Generar una matriz de 5 elementos entre un rango que prefiera usando linspace. Luego imprima la matriz para evaluar si obtuvo lo buscado.
#
# ¿De qué tipo son los datos obtenidos? ¿Qué dimensiones debería tener la matriz?

# %%
#Escriba su código aquí

# %% [markdown]
# Puede corroborar las dimensiones de su array usando el método '[shape](https://numpy.org/doc/stable/reference/generated/numpy.shape.html#numpy.shape)', que puede usar como función, pasandole la array como argumento o como método, con la sintaxis:
#
# ```
# nparray.shape
# ```

# %% [markdown]
# Por último, podemos generar nparrays a partir de listas con la siguiente sintaxis:
#
# ```
# array = np.array(lista)
# ```

# %% [markdown]
# *Ejercicio*
#
# Genere una lista - notar que debe ser numérica - con las caracteristicas que prefiera y posteriormente conviertala a un numpy array.

# %%
lista = #Completar
numpy_array_desde_lista = #completar

# %% [markdown]
# *Ejercicio*
#
# Corrobore el tipo de dato de los elementos de una de las np arrays generadas más arriba ¿Qué tipo de datos numericos se generan al definir una array por estos métodos?

# %%
#Escriba su código aquí

# %% [markdown]
# ### Acceder a datos de una numpy array

# %% [markdown]
# Podemos seleccionar un elemento de una np array de la misma forma que lo hacemos para una lista: utilizando paréntesis rectos. De forma que:
# ```
# array[i]
# ```
# devuelve el elemento con índice i de la array. Al igual que en las listas, los indices de las numpy arrays comienzan desde 0.

# %% [markdown]
# Note que las numpy arrays pueden tener más de una dimensión. En ese caso, la selección se debe hacer indicando el índice en cada dimensión. Por ejemplo, para seleccionar un elemento en una array de 3 dimensiones debe escribir:
# ```
# array[i,j,k]
# ```
# Siendo i,j y k los indices de ese elemento en cada una de las dimensiones de la matriz.

# %% [markdown]
# Puede también seleccionar regiones de la matriz utilizando los dos puntos ':'. Por ejemplo:
# ```
# array[i:j]
# ```
# nos devolverá los elementos entre i y j, no inclusive, de la array. Esta sintaxis se puede usar en arrays multidimensionales para indicar una rebaada de una de las dimensiones y no es necesario que se use en todas.
#
# Por ejemplo, podemos elegir los elementos de las filas del 1 al 5 y columna 8 de una matriz como sigue:
# ```
# array[1:5,8]
# ```

# %% [markdown]
# Si solo se indican los dos puntos, se tomarán todos los elementos en esa dimensión. Por ejemplo, el siguiente código:
# ```
# array[:,8]
# ```
# Devuelve todas las filas de la columna 8.

# %% [markdown]
# ### Algunas operaciones con numpy arrays

# %% [markdown]
# Numpy trae consigo una variedad de operaciones matemáticas integradas ([puede consultar la documentación aquí](https://numpy.org/doc/stable/reference/routines.math.html)), que se le pueden aplicar a sus numpy arrays.
#
# Para aplicar cualquiera de esas funciones a su numpy array debe seguir la siguiente sintaxis:
# ```
# np.funcion(array)
# ```
# donde debe sustituír 'funcion' por el nombre de la funcion a aplicar, por ejemplo 'sin' y 'array' por el nombre de su array.
#
# Estas funciones serán aplicadas a cada uno de los elementos de su numpy array.

# %% [markdown]
# Numpy también trae integradas diversas funciones que se aplican a su array en conjunto y no a sus elementos aislados. En la siguiente celda se muestran algunos ejemplos ¿Qué cree que hace cada uno?
#
# *Notar que estan aplicadas a una np array generada en un ejercicio más arriba. Si no realizó ese ejercicio recibirá un error al intentar correr la siguiente celda*

# %%
print(np.sum(numpy_array_desde_lista))
print(np.prod(numpy_array_desde_lista))
print(np.mean(numpy_array_desde_lista))
print(np.std(numpy_array_desde_lista))
print(np.var(numpy_array_desde_lista))
print(np.min(numpy_array_desde_lista))
print(np.max (numpy_array_desde_lista))
print(np.argmin (numpy_array_desde_lista))
print(np.argmax (numpy_array_desde_lista))

# %% [markdown]
# *Escriba su respuesta aquí*

# %% [markdown]
# Otro tipo de operación que se puede realizar sobre un numpy array es testear condiciones lógicas.
#
# Utilizando los operadores lógicos mencionados en los condicionales, podemos testear una condición, por ejemplo:
# ```
# array > 5
# ```
# esta linea de código nos devolverá una array de booleanos de la misma dimensión que nuestra array donde en la posición de cada elemento nos dirá 'True' o 'False' según si ese elemento cumple con la condición.

# %% [markdown]
# A raíz de esto, se puede filtrar una numpy array usando condicionales con la siguiente sintaxis:
# ```
# array[condicion]
# ```
# Esto genera una array con los valores que cumplen esa condición. Por ejemplo, para la condición anterior:
# ```
# array[array>5]
# ```
# retorna una array con los elementos de la array anterior que son mayores que 5.

# %% [markdown]
# Otra funcionalidad útil para trabajar con arrays es la transposición. La función '**numpy.transpose()**' cumple esta función. Tambien puede simplemente escribir el nombre de su array seguido de '.T' para generar su transpuesta.

# %% [markdown]
# # **Pandas**
#
# Pandas es un paquete de Python muy importante, diseñado para manejar, limpiar y analizar datos.
#
# Esta libreria incluye dos tipos de datos nuevos: las Series y los DataFrames.

# %% [markdown]
# ### Series
# Las series son una columna de datos o vector, indexadas, con datos ordenados que pueden ser de cualquier tipo. Son similares a las listas uni-dimensionales pero tendremos métodos especificos de pandas para manipular series.
#
# El método general para definir series es la función '**pandas.Series()**' a la cual hay que indicarle los valores de la serie, asi como el indice.

# %% [markdown]
# En la siguiente celda definimos una serie a partir de dos listas: valores de temperatura promedio por año a lo largo de varios años (datos ficticioss)

# %%
valores = [25.6, 25.3, 24.3, 14.2, 25.8, 15.3, 24.6, 27.8, 19.1, 18., 25.7]
fecha = list(range(1995, 2017, 2))

temperatura = pd.Series(data=valores, index=fecha)

# %% [markdown]
# Note que para darle los argumentos a la función primero indicamos el nombre del argumento (data, index) y seguido de un = el valor para ese argumento. Esto lo hacemos cuando una función tiene muchos posibles argumentos y por ende hay que indicarle que es lo que le estamos dando.

# %% [markdown]
# Puede acceder al índice de la serie con el método '**index**' y a los valores con el método '**values**' como sigue
# ```
# serie.index
# serie.values
# ```
# En la siguiente celda corrobore el uso de estos métodos con la serie que generamos anteriormente.

# %%
#Escriba su código aquí

# %% [markdown]
# ### DataFrames
# Los DataFrames son tablas de datos que funcionan, basicamente, como series apiladas como columnas. Es similar a una hoja de excel. Por un lado, tienen un índice que nos da los nombres de las filas y a su vez, cada columna tiene su propio nombre.
#
# De forma análoga a la creación de series, para crear un DataFrame tenemos la función '**pandas.DataFrame()**' al cual se le debe indicar los datos a guardar en el mismo. Si bien se pueden generar de muchas maneras, incluso veremos más adelante que podemos leer archivos excel o csv directo a un DataFrame, la forma más facil de hacerlo 'a mano' es usando un diccionario.

# %% [markdown]
# Veamos paso a paso cómo generar un DataFrame a partir de un diccionario:

# %%
#Primero definimos el diccionario con las secuencias de datos. Usaremos un análogo a la serie generada antes pero para varios países (datos ficticios)
data = {
    "Uruguay": [25.6, 25.3, 24.3, 14.2, 25.8, 15.3, 24.6, 27.8, 19.1, 18., 25.7],
    "Argentina": [24.5,  24.3,  33.6,  24. ,  25.7,  25.7,  24.9,  28.1,  28.7, 27.4,  15.1],
    "Brasil": [25.3,  15.2,  24.2,  24. ,  25.7,  25.2,  24.3,  17.6,  19.1,  27.4,  25.5],
    "Paraguay": [26.6, 26., 25.2, 24.6, 16.5, 25.5, 24.5, 18.6, 10.7, 18.5, 16.1],
}
#Generamos el DataFrame usando 'data' como argumento y la lista 'fecha' que definimos antes como index
temp_region = pd.DataFrame(data, index=fecha)
#Imprimimos el DataFame para observar como quedó
temp_region
# Out:
#       Uruguay  Argentina  Brasil  Paraguay
# 1995     25.6       24.5    25.3      26.6
# 1997     25.3       24.3    15.2      26.0
# 1999     24.3       33.6    24.2      25.2
# 2001     14.2       24.0    24.0      24.6
# 2003     25.8       25.7    25.7      16.5
# 2005     15.3       25.7    25.2      25.5
# 2007     24.6       24.9    24.3      24.5
# 2009     27.8       28.1    17.6      18.6
# 2011     19.1       28.7    19.1      10.7
# 2013     18.0       27.4    27.4      18.5
# 2015     25.7       15.1    25.5      16.1

# %% [markdown]
# De forma análoga a las series, puede acceder al índice del DataFrame con el método '**index**' y a los valores con el método '**values**' como sigue
# ```
# DataFrame.index
# DataFrame.values
# ```
# En la siguiente celda corrobore el uso de estos métodos con el DataFrame que generamos anteriormente.

# %%
#Escriba su código aquí

# %% [markdown]
# ### Metodos comúnes a Series y DataFrames
#
# Muchos de las manipulaciones básicas que pueden hacerse con pandas son aplicables tanto a Series como a DataFrames.

# %% [markdown]
# **Métodos .head y .tail**
#
# Estos métodos permiten imprimir los primeros (head) y los últimos (tail) n elementos de una Serie o filas de un DataFrame.
#
# La sintaxis es:
#
# ```
# nombre.head(n)
# nombre.tail(n)
# ```
# Si no se le indica el n, imprimirá los primeros (últimos) 5 elementos de una serie o 5 filas de un DataFrame.

# %% [markdown]
# *Ejercicio*
#
# Imprima los primeros 3 elementos de la serie 'temperatura' y luego las ultimas 5 filas del dataframe 'temp_region'

# %%
#Escriba su código aqui

# %% [markdown]
# **Plot**
#
# El método plot permite graficar de forma rápida los valores de una serie o de un dataframe. La sintaxis es:
# ```
# nombre.plot()
# ```
# En la siguiente celda graficaremos la serie generada. Agregue el código apropiado para graficar también el dataframe ¿Cómo lo hace? Más adelante veremos otras herramientas que nos permitiran modificar lo que graficamos y cómo lo hacemos.

# %%
temperatura.plot() #Graficamos la serie 'temperatura'

#Escriba código para graficar el dataframe 'temp_region'
# Out:
# <Axes: >

# %% [markdown]
# **Métodos .loc e .iloc**
#
# Los métodos loc e iloc sirven para acceder a datos particulares. loc sirve tanto para Series como para DataFrames mientras que iloc solo sirve para DataFrames.
#
# loc toma indices y devuelve los elementos bajo ese indice en la serie o Dataframe. Es similar a las rebanadas de listas o numpy arrays usando corchetes.
# El siguiente código:
# ```
# temp_region.loc([:,:2])
# ```
# devuelve todas las filas del dataframe 'temp_region' para las columnas entre 0 y 2 (no inclusive), es decir, las columnas 0 y 1.
#
# iloc es un poco distinto y funciona solamente en DataFrames. Es un método que nos permite seleccionar columnas por su nombre e indicar rangos de columnas de la misma manera. Por ejemplo, el siguiente código:
# ```
# temp_region.iloc['Uruguay':'Brasil']
# ```
# devuelve las columnas desde Uruguay hasta Brasil.

# %% [markdown]
# **Método .dtypes**
#
# El método dtypes es bastante simple y nos da los tipos de datos contenidos en nuestro DataFrame. Para el caso de los DataFrames, nos especificara el tipo de dato para cada una de las columnas de nuestro dataframe.
#
# *Ejercicio*
#
# Aplique el método .dtypes al dataframe generado anteriormente y evalue los tipos de datos contenidos en el.

# %%
#Escriba su código aquí

# %% [markdown]
# **Nota**: los dataframes solo reconocen algunos tipos de datos (floats, integers, booleanos, fechas y categoricos). Todo el resto lo clasificará como 'object'

# %% [markdown]
# ### Modificar DataFrames
#
# Los DataFrames son tipos de objetos mutables, lo cual quiere decir que podemos modificarlos cuanto queramos una vez definidos. Aqui veremos algunos mecanismos para modificar nuestros DataFrames

# %% [markdown]
# **Crear nuevas columnas y redefinir columnas**
#
# Dado un DataFrame, podemos crear una nueva columna con la siguiente sintaxis:
# ```
# dataFrame['nuevaColumna'] = valores
# ```
# De esta forma, asignamos los 'valores' al DataFrame en una columna bajo el nombre 'nuevaColumna'. Note que si las dimensiones de 'valores' no son copatibles con la del dataframe, esto devolverá un error. Es decir, si un DataFrame tiene 200 filas, nuestra nueva columna deberá tener 200 filas.
#
# De forma análoga, podemos redefinir una columna ya existente de nuestro DataFrame. Para ello usamos la misma sintaxis pero en lugar de 'nuevaColumna' ponemos el nombre de la columna que deseamos modificar.

# %% [markdown]
# *Ejercicio*
#
# En la siguiente celda le brindamos datos sobre temperatura en chile. Agreguelos a nuestro DataFrame 'temp_region'

# %%
chile = [16.6, 28., 25.8, 16.6, 26.5, 35.5, 24.8, 28.6, 22.7, 20.5, 19.1]
#Ingrese su código aquí

# %% [markdown]
# ** Cambiar valores dentro de un Dataframe **
#
# De forma muy similar a cómo podemos cambiar los valores de una columna ya generada, podemos cambiar uno o varios valores de un DataFrame con la siguiente sintaxis:
# ```
# dataFrame.loc[indice, columna] = valor
# ```
# 'indice' puede ser un solo valor o un rango.

# %% [markdown]
# *Ejercicio*
#
# Revisando sus registros de temperatura nota que el valor registrado para chile en 1995 es bastante bajo (16.6). Se fija en sus registros manuales nota que el valor real era 26.6 y que debe haber tenido un typo cuando los pasó a Python.
#
# Remedie su error en la siguiente celda

# %%
#Escriba aquí su código

# %% [markdown]
# **Cambiar el nombre de una columna**
#
# Poder cambiarle el nombre a las columnas de un DataFrame nos sirve porque muchas veces las bases de datos vienen con nombres ilegibles como códigos. Pandas trae un método integrado llamado 'rename' que nos permite renombrar las columnas de un DataFrame.
#
# Para aplicar este método debemos definir un diccionario con los nombres antiguos y los nuevos de las columnas y pasarselos como argumento. En la siguiente celda lo hacemos para cambiar los nombres de las columnas de nuestro dataFrame 'temp_region':

# %%
nombres_nuevos = {
    'Uruguay':'Uy'
    'Argentina' : 'Arg'
    'Brasil' : 'Br'
    'Paraguay': 'Par'
    'Chile': 'Chi'
}

temp_region = temp_region.rename(columns=nombres_nuevos)
temp_region.head()

# %% [markdown]
# # **Matplotlib**

# %% [markdown]
# Matplotlib es una librería gráfica de Python que nos permite generar múltiples tipos de gráficos y visualizaciones. En este cuaderno haremos solamente una breve introducción a lo que se puede hacer con esta librería pero por más información puede consultar la [documentación](https://matplotlib.org).

# %% [markdown]
# ## Intro
#
# Comencemos con un gráfico simple. La función más simple de usar en matplotlib para graficar es '**plt.plot()**'. Esta función realiza gráficos de linea a menos que le indiquemos otra cosa, a partir de dos series de datos (si solo se le pasa una serie genera el eje X de forma automática).
#
# **Nota**: recuerde que 'plt' es el alias con el cual importamos matplotlib, por ende lo usamos en lugar del nombre completo de la librería.

# %%
#Generemos dos vectores x e y
x = [1,2,3,4,5,6]
y = [10,20,30,40,50,60]

#Grafiquemos estos dos vectores usando matplotlib
plt.plot(x,y)

#Le pedimos que nos muestre lo graficado
plt.show()

# %% [markdown]
# La sintaxis observada más arriba es la general para hacer un gráfico con matplotlib. Notar que debemos pedirle, con '**plt.show()**' que nos muestre el gráfico. Esto no siempre es necesario pero si lo es cuando corremos python en google collab o jupyter notebooks.
#
# Agreguemosle ahora un titulo y nombres a los ejes.

# %%
#Grafiquemos estos dos vectores usando matplotlib
plt.plot(x,y)
#Definimos el titulo del gráfico
plt.title('Grafico')
#Definimos los nombres de los ejes
plt.xlabel('Eje x')
plt.ylabel('Eje y')
#Le pedimos que nos muestre lo graficado
plt.show()

# %% [markdown]
# Otro método que puede resultar de utilidad es el método '.figure()' que nos permite definir a la figura y sus caracteristicas como el tamaño. Esto puede ser especialmente relevante cuando querramos posteriormente exportar una figura generada en python.

# %%
#Grafiquemos estos dos vectores usando matplotlib
plt.plot(x,y)
#Definimos el titulo del gráfico
plt.title('Grafico')
#Definimos la figura
plt.figure(figsize=(100, 120))
#Le pedimos que nos muestre lo graficado
plt.show()

# %% [markdown]
# Si queremos graficar más de un gráfico en una misma figura podemos usar el método '**.subplots()**'. La sintaxis es:
# ```
# plt.subplot(nrows,ncols,indice)
# ```
# Los primeros dos argumentos nos indican en cuantas filas y columnas, respectivamente queremos que se divida nuestra figura. El indice nos dice en cual de esas subfiguras graficar el grafico particular.
#
# Veamos un ejemplo

# %%
#Generamos las subplots
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('Subplot 1')

#Generamos la otra subplot
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title('Subplot 2')

#Mostramos la figura
plt.show()

# %% [markdown]
# ## Definir una figura
#
# Acabamos de generar gráficos de forma aislada, lo cual hace que su personalización se vuelva un poco más complicada. Lo más prolijo a la hora de graficar es generar primero una figura y un set de ejes. Luego, graficaremos dentro de esa figura y set de ejes.

# %%
#Creamos una figura (fig) y un set de ejes (ax)
fig, ax = plt.subplots() #notar que esta funcion es diferente a la usada anteriormente (subplot)

#graficamos sobre nuestra figura
ax.plot(x,y)

#Seteamos los nombres y titulo
ax.set(xlabel='Eje x', ylabel='Eje y', title='Grafico')

#mostramos el gráfico
plt.show()

# %% [markdown]
# En el código propuesto, podriamos dar como argumento a .subplots() dimensiones para generar mas de una subplot.

# %% [markdown]
# ## Graficos de Dispersion
#
# Matplotlib tiene una gran cantidad de funciones para graficar todo tipo de gráficos. Aquí veremos simplemente cómo graficar un gráfico de dispersión. Para eso tenemos la función '**plt.scatter()**'
#
# Veamos un ejemplo:

# %%
#Creamos una figura (fig) y un set de ejes (ax)
fig, ax = plt.subplots()

#graficamos sobre nuestra figura
ax.scatter(x,y)

#Seteamos los nombres y titulo
ax.set(xlabel='Eje x', ylabel='Eje y', title='Grafico')

#mostramos el gráfico
plt.show()

# %% [markdown]
# ## Personalización
#
# Podemos personalizar de diversas maneras nuestro gráfico. Desde el color de nuestros puntos, la forma y tamaño de los puntos, el tamaño de la linea, la opacidad, el fondo de la gráfica y muchas cosas que se le puedan ocurrir.
#
# Aquí veremos algunos ejemplos. Para gráficos y visualizaciones más complejas y personalizables hay otras librerias disponibles, como [Seaborn](https://seaborn.pydata.org).

# %% [markdown]
# Arranquemos personalizando el color de nuestro gráfico. Para esto, la función plot tiene un argumento 'color' que podemos setear como queramos. Matplotlib trae algunos [colores incorporados](https://matplotlib.org/stable/gallery/color/named_colors.html) que se pueden llamar por su nombre, o puede incluso darle un código HEX con el color especifico que prefiera.

# %%
# Definimos la figura
fig, ax = plt.subplots(figsize=(10, 6))

# Definimos la gráfica
ax.plot(x,
        y,
        color = 'red')

# Seteamos los titulos
ax.set(title = "Gráfico",
       xlabel = "Eje X",
       ylabel = "Eje y")

plt.show()

# %% [markdown]
# Cambiemos ahora la forma de los puntos en nuestro gráfico de dispersión. De forma similar a lo que vimos para el color, hay un parámetro 'marker' que tiene la función scatter asi como la función plot. Puede consultar [aquí](https://matplotlib.org/1.4.1/api/markers_api.html) los diferentes códigos para los diferentes puntos que puede usar

# %%
# Definimos la figura
fig, ax = plt.subplots(figsize=(10, 6))

# Definimos la gráfica
ax.plot(x,
        y,
        color = 'red',
        marker = 'v')

# Seteamos los titulos
ax.set(title = "Gráfico",
       xlabel = "Eje X",
       ylabel = "Eje y")

plt.show()

# %% [markdown]
# El úlimo ejemplo de personalización que veremos es la opacidad de nuestro gráfico. Esto es especialmente relevante en graficos de dispersion donde se acumulan muchos puntos juntos. Esta se setea con el argumento 'alpha' que va desde 0 a 1, siendo 1 el color normal y 0 completamente transparente.
#
# Veamos un ejemplo:

# %%
# Definimos la figura
fig, [ax1,ax2] = plt.subplots(nrows=1,ncols=2) #definimos una figura con dos subplots

# Graficamos la primera con opacidad =1 (default)
ax1.plot(x,
        y,
        color = 'darkblue',
        marker = 'v')
#Graficamos la segunda con opacidad = 0.5
ax2.plot(x,
        y,
        color = 'darkblue',
        marker = 'v',
         alpha=0.5)

plt.show()

# %% [markdown]
# Alli se puede ver claramente el efecto de modificar el parámetro alpha. De paso vimos como generar dos subplots en una misma figura con la sintaxis que venimos trabajando.

# %% [markdown]
# # **Ejercicios extra**

# %% [markdown]
# ## ***Ejercicio 1***: *Manipulación y visualización de una imágen usando numpy y matplotlib.*
#
# En este ejercicio importaremos una imagen usando el paquete '[skimage](https://scikit-image.org)' la cual visualizaremos usando una función integrada de matplotlib ('imshow()'). Para esto debemos leer la imágen como una numpy array.
#
# Usando manipulaciones básicas de numpy arrays podremos modificar esta imagen de diferentes maneras, como rotarla y espejarla.

# %%
#El siguiente código carga la imagen desde el paquete skimage.io
from skimage import io #esta sintaxis permite cargar solamente un subpaquete (en este caso 'io') desde una libreria más grande (en este caso skimage)
imagen = io.imread('https://i.natgeofe.com/n/548467d8-c5f1-4551-9f58-6817a8d2c45e/NationalGeographic_2572187_square.jpg') #cargamos la imagen desde el URL
# Out:
# numpy.ndarray

# %% [markdown]
# A continuación evaluaremos la forma de esta numpy array que generamos.

# %%
#Escribe tu código aquí
# Out:
# (3072, 3072, 3)

# %% [markdown]
# Cuando leemos una imagen como una matriz tendremos 3 dimensiones: 2 dimensiones de pixeles y una tercera que nos da el color o intensidad del pixel. Cuando la imágen está a color esta tercera dimensión tiene 3 canales (RGB). La siguiente celda visualiza la imagen cargada ¿Es consistente con las dimensiones que observó anteriormente?

# %%
plt.imshow(imagen)

# %% [markdown]
# A continuación genere una nueva np array seleccionando diferentes regiones de la imagen usando lo que aprendió anteriormente para acceder a elementos de una numpy array.
#
# *sugerencia*: note que las primeras dos dimensiones definen la región de la imagen y la tercera su color.

# %%
seleccion = # Completar
plt.imshow(seleccion)

# %% [markdown]
# Ahora transponga las primeras dos dimensiones de la matriz ¿Qué espera que pase con la imágen? Pruebelo

# %%
#Escriba su código aquí

# %% [markdown]
# ## ***Ejercicio 2***
# Una función muy útil de numpy es la función ['where'](https://numpy.org/doc/stable/reference/generated/numpy.where.html) que nos devuelve los indices de una numpy array donde se cumple una determinada condición.
#
# Lea la documentación de la función y escriba una función que devuelva una numpy array de la misma forma que la entrada pero con 0 y 1 en cada elemento segun si se cumple o no una determinada condicion.
#
# *sugerencia*: recuerde que se puede generar una numpy array con las dimensiones deseadas y llenarlas de 0

# %%
def donde(condicion, array):
  nueva_array = np.zeros(shape=array.shape)
  se_cumple = np.where(condicion, array)
  for i in se_cumple.shape[0]: #funciona para 1D arrays
    if se_cumple[i]:
      nueva_array[i] = 1

  return nueva_array

# %% [markdown]
# ## ***Ejercicio 3***
# Una funcionalidad muy útil de Numpy es el modulo 'random'. En general, los paquetes grandes como los que hemos trabajado se componen de varios modulos, que incluso podemos importar por separado. En este ejercicio usaremos el modulo random de numpy para generar una matriz con numeros al azar en un determinado rango y luego muestrear aleatoriamente de esa misma matriz.

# %% [markdown]
# Para comenzar, tenga a mano la [documentacion](https://numpy.org/doc/stable/reference/random/index.html) del modulo random. Alli encontrara una introduccion general al modulo al igual que la documentacion de cada una de las funciones que contiene.
# Comenzaremos importando el modulo por separado de la importacion de numpy.

# %%
import numpy as np #Asi importamos normalmente numpy
from numpy import random #de esta forma importamos solo el modulo random

# %% [markdown]
# Si importamos random por su cuenta, cuando queramos referir a una funcion de este modulo deberemos hacerlo como sigue:
# ```
# random.funcion
# ```
# En caso de simplemente importar numpy, podemos llamar a las funciones de random (o de cualquier otro modulo) como sigue:
# ```
# np.modulo.funcion
# ```

# %% [markdown]
# Ahora si, comencemos con el ejercicio. Utilizaremos la funcion '[rand](https://numpy.org/doc/stable/reference/random/generated/numpy.random.rand.html)' para generar una numpy array de 3x3 con numeros random.

# %%
# Primero definimos el numero de filas y columnas que queremos para nuestra matriz
num_filas = 3
num_cols = 3
# Generamos nuestra matriz
random_array = random.rand(num_filas, num_cols)
# Imprimimos la array para ver que nos genero
print("Array:\n", random_array)
# Out:
# Array:
#  [[0.27507797 0.33168899 0.12956426]
#  [0.8234062  0.33480345 0.79534302]
#  [0.9273973  0.06975665 0.04364738]]

# %% [markdown]
# Notaran que los numeros que nos generó estan todos entre 0 y 1. Esto es porque la funcion rand solo genera numeros en este rango. Suponga que ahora queremos una matriz con numeros entre 10 y 20, al azar. Genere el codigo necesario para lograrlo.

# %%
# Primero definimos el numero de filas y columnas que queremos para nuestra matriz
num_filas = 3
num_cols = 3
# Generamos nuestra matriz
random_array = random.rand(num_filas, num_cols)
random_array_nuevo_rango = 10 + random_array * 10
# Imprimimos las arrays para ver que nos genero
print("Array:\n", random_array)
print("Array entre 10 y 20:\n", random_array_nuevo_rango)
# Out:
# Array:
#  [[0.30041157 0.63838978 0.99103126]
#  [0.623714   0.06266846 0.98894682]
#  [0.51207054 0.56092617 0.46879204]]
# Array entre 10 y 20:
#  [[13.00411567 16.38389781 19.91031262]
#  [16.23713998 10.62668464 19.88946817]
#  [15.12070538 15.60926166 14.68792038]]

# %% [markdown]
# Ahora pasemos al muestreo aleatorio de una array. Para esto utilizaremos la función '[choice](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html)'.
#
# Esta funcion funciona sobre arrays de 1 dimensión. La sintaxis es como sigue:
# ```
# muestra = random.choice(array, size=n)
# ```
# Siendo n el tamaño de la muestra que queremos. Muestreemos 2 elementos al azar del array que generamos. Como choice acepta solo arrays de 1D, primero debemos 'aplastar' nuestra array a 1 dimension. Para esto usaremos el método '[.flatten()](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.flatten.html)'.

# %%
muestra = random.choice(random_array.flatten(), size=2)
print("Muestra:", muestra)
# Out:
# Muestra: [0.63838978 0.623714  ]

# %% [markdown]
# A continuación, genere una muestra de n=3 de la array que genero con valores entre 10 y 20.

# %%
muestra2 = random.choice(random_array_nuevo_rango.flatten(), size=3)
print("Muestra:", muestra2)
# Out:
# Muestra: [19.91031262 16.38389781 10.62668464]

# %% [markdown]
# Para terminar, escriba una función que:
# - Tome como argumentos un rango de numeros, un tamaño de array (nfilas y ncolumnas) y un tamaño de muestra
# - Devuelva un array 2D del tamaño indicado y una muestra del tamaño indicado de esa array.

# %%
def funcion(n_filas, n_columnas, rango, n_muestra):
  array = rango[0] + random.rand(n_filas, n_columnas) * (rango[1] - rango[0])
  muestra = random.choice(array.flatten(), size=n_muestra)
  return array, muestra

array, muestra = funcion(3,2,[0,20], 3)
print(array, muestra)
# Out:
# [[17.01883126 15.31719512]
#  [17.25197713 12.38643627]
#  [ 4.05050323 17.49922063]] [17.01883126  4.05050323 17.25197713]
